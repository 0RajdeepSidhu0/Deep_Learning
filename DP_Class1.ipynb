# %% [markdown]
# <a href="https://colab.research.google.com/github/0RajdeepSidhu0/Deep_Learning/blob/main/DP_Class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Cost_of_Living_Index_by_Country_2024.csv')

# %%
print(df.describe())
# Out:
#              Rank  Cost of Living Index  Rent Index  \
# count  121.000000            121.000000  121.000000
# mean    61.000000             43.555372   16.052893
# std     35.073732             16.147574   11.412267
# min      1.000000             18.800000    2.400000
# 25%     31.000000             30.200000    8.500000
# 50%     61.000000             39.500000   12.400000
# 75%     91.000000             52.800000   20.100000
# max    121.000000            101.100000   67.200000
#
#        Cost of Living Plus Rent Index  Groceries Index  \
# count                      121.000000       121.000000
# mean                        30.357851        44.228926
# std                         13.263721        17.055109
# min                         11.100000        17.500000
# 25%                         19.800000        31.600000
# 50%                         27.000000        40.500000
# 75%                         37.000000        53.700000
# ...

# %%
import skimage as ski

camera = ski.data.camera()
# ... or any other NumPy array!
edges = ski.filters.sobel(camera)
ski.io.imshow(edges)
ski.io.show()

# %%
import os
filename = os.path.join(ski.data_dir, '/content/drive/MyDrive/Colab Notebooks/20230226_180531.jpg')
my_img = ski.io.imread(filename)
edges = ski.filters.sobel(my_img)
ski.io.imshow(edges)
ski.io.show()
